# %% [markdown]
# # 数学の基礎
#
# 6/40問(15%)

# %% [markdown]
# ## 3-1:数式を読むための基礎知識
#
# ### 数式と記号
#
# * ギリシャ文字
#
# 省略
#
# * 集合
#     * ある要素ｘが、集合Sに属していること
# $x \in S$
#     * ある要素yが、集合Sに属していないこと
# $y \notin S$
#     * 和集合
# $A \cap B$
#     * 積集合
# $A \cup B$
#
# * 数のまとまり
#     * n個のまとまりを表現
#
# $　x_1,x_2,...,x_n$
#
# $x_i(i=1,2,...,n)$
#
# * 数式と番号
#
# 省略
#
# ### 数学記号
#
# * 足し算の繰り返し
#
# $$ \sum_{i=1}^{n} x_i $$
#
# * 掛け算の繰り返し
#
# $$ \prod_{i=1}^{n} x_i $$
#
#
# * 特殊な定数
#
# ### 関数の基本
#
# * 関数の書き方
#
# * 少し特殊な関数
#
# * 指数関数
#
# * 対数関数
#
# * 三角関数
#
# * 双曲線関数
#
# ## 3-2:線形代数
#
# ### ベクトルとその演算
#
# * ベクトルとは
#
# * ベクトルの演算
#
# * ノルム
#
# * 内積
#
# ### 行列とその演算
#
# * 行列とは
#
# * 行列の演算
#
# * 行列の掛け算
#
# * 行列の分解
#
#
# ## 3-3:基礎解析
#
# ### 微分と積分の意味
#
# * 積分は面積
#
# * 微分は傾き
#
# ### かんたんな関数の微分と積分
#
# * いろいろな関数の微分と積分
#
# ### 微分と関数の値
#
# ### 偏微分
#
#
#
# ## 3-4:確率と統計
#
# ### 統計の基礎
# * 代表値
# * 最小値
# * 平均値
# * 中央値
# * 最頻値
# * ばらつきの指標
# * 度数分布表
#
# ### データの可視化方法
# * ヒストグラム
# * 箱ひげ図
# * 散布図
#
# ### データとその関係性
#
# * 相関係数
# * その他の相関係数
#
# ### 確率
# * 確率の基礎
# * 条件付き確率
#
# ### 確率分布
# * 確率変数と確率分布
# * 期待値
# * 分散
#
# ### 確率と関数
#
# * 離散一様分布
# * 正規分布
